# %%
#Import Dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import psycopg2
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

#Create Engine/Connection to postgressql

engine = create_engine('postgres://postgres:postgres@localhost:5432/employees')
connection = engine.connect()

# %%
# Check if engine/execute is running correctly by printing out data from departments table

data = engine.execute('SELECT * FROM departments LIMIT 5')
for record in data:
    print(record)
# Out:
# ('d001', 'Marketing')
# ('d002', 'Finance')
# ('d003', 'Human Resources')
# ('d004', 'Production')
# ('d005', 'Development')

# %%
# Set up inspector to read in table names and confirm they all have been connceted to via the engine

inspector = inspect(engine)

inspector.get_table_names()
# Out:
# ['employees', 'departments', 'dept_emp', 'dept_manager', 'salaries', 'titles']

# %%
# View data in the salaries column to view formatting

engine.execute('SELECT * FROM salaries LIMIT 10').fetchall()
# Out:
# [(10001, 60117, datetime.date(1986, 6, 26), datetime.date(1987, 6, 26), 1),
#  (10002, 65828, datetime.date(1996, 8, 3), datetime.date(1997, 8, 3), 2),
#  (10003, 40006, datetime.date(1995, 12, 3), datetime.date(1996, 12, 2), 3),
#  (10004, 40054, datetime.date(1986, 12, 1), datetime.date(1987, 12, 1), 4),
#  (10005, 78228, datetime.date(1989, 9, 12), datetime.date(1990, 9, 12), 5),
#  (10006, 40000, datetime.date(1990, 8, 5), datetime.date(1991, 8, 5), 6),
#  (10007, 56724, datetime.date(1989, 2, 10), datetime.date(1990, 2, 10), 7),
#  (10008, 46671, datetime.date(1998, 3, 11), datetime.date(1999, 3, 11), 8),
#  (10009, 60929, datetime.date(1985, 2, 18), datetime.date(1986, 2, 18), 9),
#  (10010, 72488, datetime.date(1996, 11, 24), datetime.date(1997, 11, 24), 10)]

# %%
# Set up refelction to pull table in to pandas and query

Base = automap_base()
Base.prepare(engine, reflect=True)
Salaries = Base.classes.salaries

# %%
# Create a Session

session = Session(engine)

# %%
# Query Salary column of Salaries table in desc order to confirm the highest salary in the table

results = session.query(Salaries.salary).order_by(Salaries.salary.desc()).all()

results = pd.DataFrame(results)

results.head()
# Out:
#    salary
# 0  129492
# 1  127238
# 2  127041
# 3  126703
# 4  125469

# %%
# Use Pandas to load a query statement directly into the DataFrame

stmt = session.query(Salaries).statement
df1 = pd.read_sql_query(stmt, session.bind)
df1
# Out:
#         emp_no  salary   from_date     to_date  salary_id
# 0        10001   60117  1986-06-26  1987-06-26          1
# 1        10002   65828  1996-08-03  1997-08-03          2
# 2        10003   40006  1995-12-03  1996-12-02          3
# 3        10004   40054  1986-12-01  1987-12-01          4
# 4        10005   78228  1989-09-12  1990-09-12          5
# ...        ...     ...         ...         ...        ...
# 300019  499995   40000  1997-06-02  1998-06-02     300020
# 300020  499996   58058  1996-05-13  1997-05-13     300021
# 300021  499997   49597  1987-08-30  1988-08-29     300022
# 300022  499998   40000  1993-12-27  1994-12-27     300023
# 300023  499999   63707  1997-11-30  1998-11-30     300024
#
# [300024 rows x 5 columns]

# %%
# Create new datafram for salary

salary_df = df1[['emp_no', 'salary']]

salary_df
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
# Create bins and labels to be used to be used for Salary Range

bins = [39999, 49999, 59999, 69999, 79999, 89999, 99999, 109999, 119999,
        129999, 150999]

labels = ["40K-49K", "50K-59K", "60K-69K", "70K-79K", "80K-89K", "90K-99K",
         "100K-109K", "110K-119K", "120K-129K", ">=130K"]

# %%
# Slice bins together with salary_df

salary_df["salary_summary"] = pd.cut(salary_df["salary"], bins=bins, labels=labels)

salary_df
# Out:
# C:\Users\alexr\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         emp_no  salary salary_summary
# 0        10001   60117        60K-69K
# 1        10002   65828        60K-69K
# 2        10003   40006        40K-49K
# 3        10004   40054        40K-49K
# 4        10005   78228        70K-79K
# ...        ...     ...            ...
# 300019  499995   40000        40K-49K
# 300020  499996   58058        50K-59K
# 300021  499997   49597        40K-49K
# 300022  499998   40000        40K-49K
# 300023  499999   63707        60K-69K
#
# [300024 rows x 3 columns]

# %%
# group data together by salary_summary and perform count funtion to get counts for each salary range

grouped_data = salary_df.groupby("salary_summary")

grouped_df = grouped_data["salary_summary"].count()

grouped_df = pd.DataFrame(grouped_df)

grouped_df = grouped_df.rename(columns={'salary_summary':'count'})

salaries_df = grouped_df.reset_index()

salaries_df
# Out:
#   salary_summary   count
# 0        40K-49K  158465
# 1        50K-59K   57915
# 2        60K-69K   41413
# 3        70K-79K   24814
# 4        80K-89K   11845
# 5        90K-99K    4284
# 6      100K-109K    1069
# 7      110K-119K     195
# 8      120K-129K      24
# 9         >=130K       0

# %%
# plot Salary Ranges for Employees table

plt.figure(figsize=(10,5))

y_axis = salaries_df['count'].tolist()

x_axis = np.arange(len(y_axis))

ticks = ["40K-\n49K", "50K-\n59K", "60K-\n69K", "70K-\n79K", "80K-\n89K", "90K-\n99K",
         "100K-\n109K", "110K-\n119K", "120K-\n129K", ">=130K"]

plt.bar(x_axis, y_axis, color='b', align='center')

tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, ticks)

plt.title("Salary Ranges for Employees")

plt.xlabel("Salary")

plt.ylabel("Number of Employees")

plt.tight_layout()

#plt.savefig("../images/histogram.png")

# %%
# Set up reflection for Titles table and read in sql query on table using pandas

Titles = Base.classes.titles

stmt = session.query(Titles).statement
df2 = pd.read_sql_query(stmt, session.bind)
df2
# Out:
#         emp_no            title   from_date     to_date  title_id
# 0        10001  Senior Engineer  1986-06-26  9999-01-01         1
# 1        10002            Staff  1996-08-03  9999-01-01         2
# 2        10003  Senior Engineer  1995-12-03  9999-01-01         3
# 3        10004         Engineer  1986-12-01  1995-12-01         4
# 4        10004  Senior Engineer  1995-12-01  9999-01-01         5
# ...        ...              ...         ...         ...       ...
# 443303  499997         Engineer  1987-08-30  1992-08-29    443304
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01    443305
# 443305  499998     Senior Staff  1998-12-27  9999-01-01    443306
# 443306  499998            Staff  1993-12-27  1998-12-27    443307
# 443307  499999         Engineer  1997-11-30  9999-01-01    443308
#
# [443308 rows x 5 columns]

# %%
# Merge salary table with titles table

merged_data = pd.merge(df2, df1, on='emp_no', how='inner', indicator=True)

merged_data.head(10)
# Out:
#    emp_no            title from_date_x   to_date_x  title_id  salary  \
# 0   10001  Senior Engineer  1986-06-26  9999-01-01         1   60117
# 1   10002            Staff  1996-08-03  9999-01-01         2   65828
# 2   10003  Senior Engineer  1995-12-03  9999-01-01         3   40006
# 3   10004         Engineer  1986-12-01  1995-12-01         4   40054
# 4   10004  Senior Engineer  1995-12-01  9999-01-01         5   40054
# 5   10005     Senior Staff  1996-09-12  9999-01-01         6   78228
# 6   10005            Staff  1989-09-12  1996-09-12         7   78228
# 7   10006  Senior Engineer  1990-08-05  9999-01-01         8   40000
# 8   10007     Senior Staff  1996-02-11  9999-01-01         9   56724
# 9   10007            Staff  1989-02-10  1996-02-11        10   56724
#
#   from_date_y   to_date_y  salary_id _merge
# 0  1986-06-26  1987-06-26          1   both
# 1  1996-08-03  1997-08-03          2   both
# 2  1995-12-03  1996-12-02          3   both
# ...

# %%
# Create new dataframe with the required fields for the next plot

merged_df = merged_data[['title', 'salary']]

merged_df
# Out:
#                   title  salary
# 0       Senior Engineer   60117
# 1                 Staff   65828
# 2       Senior Engineer   40006
# 3              Engineer   40054
# 4       Senior Engineer   40054
# ...                 ...     ...
# 443303         Engineer   49597
# 443304  Senior Engineer   49597
# 443305     Senior Staff   40000
# 443306            Staff   40000
# 443307         Engineer   63707
#
# [443308 rows x 2 columns]

# %%
# Group dataframe by title and run mean function on the dataframe to get the average salary per title

groupby_title = merged_df.groupby('title')

group_by = round(groupby_title["salary"].mean())

title_avg = pd.DataFrame(group_by)

title_avg_df = title_avg.reset_index()

title_avg_df
# Out:
#                 title   salary
# 0  Assistant Engineer  48493.0
# 1            Engineer  48540.0
# 2             Manager  51531.0
# 3     Senior Engineer  48507.0
# 4        Senior Staff  58503.0
# 5               Staff  58465.0
# 6    Technique Leader  48581.0

# %%
# Plot bar chart of Average Salry by Title

plt.figure(figsize=(10,5))

y_axis = title_avg_df['salary'].tolist()

x_axis = np.arange(len(y_axis))

ticks = title_avg_df['title'].tolist()

plt.bar(x_axis, y_axis, color='b', align='center')

tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, ticks)

plt.title("Average Salary by Title")

plt.xlabel("Title")

plt.ylabel("Average Salary")

plt.tight_layout()

#plt.savefig("../images/bar.png")
